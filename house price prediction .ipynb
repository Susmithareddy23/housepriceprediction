# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house=pd.read_csv(r'C:\Users\sushmitha\bangalore house price prediction OHE-data.csv')
house
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0      3.0      2.0  150.00          1672.0    3     8971.291866
# 1      3.0      3.0  149.00          1750.0    3     8514.285714
# 2      3.0      2.0  150.00          1750.0    3     8571.428571
# 3      2.0      2.0   40.00          1250.0    2     3200.000000
# 4      2.0      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115   3.0      2.0  325.00          2900.0    3    11206.896552
# 7116   3.0      1.0   84.83          1780.0    3     4765.730337
# 7117   2.0      1.0   48.00           880.0    2     5454.545455
# 7118   2.0      1.0   55.00          1000.0    2     5500.000000
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %%
house.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0   3.0      2.0  150.0          1672.0    3     8971.291866
# 1   3.0      3.0  149.0          1750.0    3     8514.285714
# 2   3.0      2.0  150.0          1750.0    3     8571.428571
# 3   2.0      2.0   40.0          1250.0    2     3200.000000
# 4   2.0      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %%
house.tail()
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 7115   3.0      2.0  325.00          2900.0    3    11206.896552
# 7116   3.0      1.0   84.83          1780.0    3     4765.730337
# 7117   2.0      1.0   48.00           880.0    2     5454.545455
# 7118   2.0      1.0   55.00          1000.0    2     5500.000000
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 7115                              1                        0
# 7116                              1                        0
# 7117                              0                        0
# 7118                              0                        0
# 7119                              0                        0
#
#       area_typePlot  Area  availability_Ready To Move  ...  \
# 7115                    0                           1  ...
# 7116                    0                           0  ...
# ...

# %%
house.describe()
# Out:
#               bath      balcony        price  total_sqft_int          bhk  \
# count  7120.000000  7120.000000  7120.000000     7120.000000  7120.000000
# mean      2.390871     1.572759    96.454991     1479.729806     2.465169
# std       0.876822     0.770583   116.185034      913.779769     0.841520
# min       1.000000     0.000000    10.000000      350.000000     1.000000
# 25%       2.000000     1.000000    49.230000     1100.000000     2.000000
# 50%       2.000000     2.000000    69.000000     1255.000000     2.000000
# 75%       3.000000     2.000000   104.000000     1640.250000     3.000000
# max       9.000000     3.000000  2912.000000    30400.000000     9.000000
#
#        price_per_sqft  area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# count     7120.000000                    7120.000000              7120.000000
# mean      5923.806855                       0.750702                 0.182303
# ...

# %%
house.max()
# Out:
# bath                               9.0
# balcony                            3.0
# price                           2912.0
# total_sqft_int                 30400.0
# bhk                                9.0
#                                 ...
# location_Hosur Road                1.0
# location_Horamavu Banaswadi        1.0
# location_Domlur                    1.0
# location_Mahadevpura               1.0
# location_Tumkur Road               1.0
# Length: 108, dtype: float64

# %%
house.min()
# Out:
# bath                             1.0
# balcony                          0.0
# price                           10.0
# total_sqft_int                 350.0
# bhk                              1.0
#                                ...
# location_Hosur Road              0.0
# location_Horamavu Banaswadi      0.0
# location_Domlur                  0.0
# location_Mahadevpura             0.0
# location_Tumkur Road             0.0
# Length: 108, dtype: float64

# %%
house.mode()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0   2.0      1.0   75.0          1200.0    2          5000.0
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
#
#    location_Kalena Agrahara  location_Horamavu Agara  location_Vidyaranyapura  \
# 0                         0                        0                        0
#
#    location_BTM 2nd Stage  location_Hebbal Kempapura  location_Hosur Road  \
# 0                       0                          0                    0
#
#    location_Horamavu Banaswadi  location_Domlur  location_Mahadevpura  \
# 0                            0                0                     0
#
#    location_Tumkur Road
# 0                     0
#
# [1 rows x 108 columns]

# %%
house.median()
# Out:
# bath                              2.0
# balcony                           2.0
# price                            69.0
# total_sqft_int                 1255.0
# bhk                               2.0
#                                 ...
# location_Hosur Road               0.0
# location_Horamavu Banaswadi       0.0
# location_Domlur                   0.0
# location_Mahadevpura              0.0
# location_Tumkur Road              0.0
# Length: 108, dtype: float64

# %%
house.mean()
# Out:
# bath                              2.390871
# balcony                           1.572759
# price                            96.454991
# total_sqft_int                 1479.729806
# bhk                               2.465169
#                                   ...
# location_Hosur Road               0.002949
# location_Horamavu Banaswadi       0.002809
# location_Domlur                   0.002809
# location_Mahadevpura              0.002809
# location_Tumkur Road              0.002809
# Length: 108, dtype: float64

# %%
house.shape
# Out:
# (7120, 108)

# %%
pred_test = house.iloc[3]

# %%
pred_test['type'] = 1
pred_test.drop(['price','balcony'],inplace=True)
#pred_test.drop('balcony',inplace=True)
pred_test
# Out:
# C:\Users\sushmitha\AppData\Local\Temp\ipykernel_19384\2735753457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_test['type'] = 1
# C:\Users\sushmitha\AppData\Local\Temp\ipykernel_19384\2735753457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_test['type'] = 1
# C:\Users\sushmitha\AppData\Local\Temp\ipykernel_19384\2735753457.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
house.isnull().sum()
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
house.dropna()
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0      3.0      2.0  150.00          1672.0    3     8971.291866
# 1      3.0      3.0  149.00          1750.0    3     8514.285714
# 2      3.0      2.0  150.00          1750.0    3     8571.428571
# 3      2.0      2.0   40.00          1250.0    2     3200.000000
# 4      2.0      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115   3.0      2.0  325.00          2900.0    3    11206.896552
# 7116   3.0      1.0   84.83          1780.0    3     4765.730337
# 7117   2.0      1.0   48.00           880.0    2     5454.545455
# 7118   2.0      1.0   55.00          1000.0    2     5500.000000
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7120 entries, 0 to 7119
# Columns: 108 entries, bath to location_Tumkur Road
# dtypes: float64(5), int64(103)
# memory usage: 5.9 MB

# %%
house.columns
# Out:
# Index(['bath', 'balcony', 'price', 'total_sqft_int', 'bhk', 'price_per_sqft',
#        'area_typeSuper built-up  Area', 'area_typeBuilt-up  Area',
#        'area_typePlot  Area', 'availability_Ready To Move',
#        ...
#        'location_Kalena Agrahara', 'location_Horamavu Agara',
#        'location_Vidyaranyapura', 'location_BTM 2nd Stage',
#        'location_Hebbal Kempapura', 'location_Hosur Road',
#        'location_Horamavu Banaswadi', 'location_Domlur',
#        'location_Mahadevpura', 'location_Tumkur Road'],
#       dtype='object', length=108)

# %%
house.sort_values(by=["availability_Ready To Move"])
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
# 2016   2.0      1.0   65.58          1128.0    2     5813.829787
# 2013   3.0      2.0   83.00          1571.0    3     5283.259071
# 2011   1.0      1.0   13.50           530.0    1     2547.169811
# 2010   1.0      0.0   13.31           605.0    1     2200.000000
# ...    ...      ...     ...             ...  ...             ...
# 2612   2.0      2.0   46.00          1243.0    2     3700.724055
# 2611   2.0      2.0   46.00          1200.0    2     3833.333333
# 2609   3.0      2.0   97.00          1735.0    3     5590.778098
# 2634   3.0      2.0  131.00          1756.0    3     7460.136674
# 3559   3.0      2.0   56.00          1464.0    3     3825.136612
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 7119                              0                        0
# ...

# %%
missing_vals = house['area_typeBuilt-up  Area'].isnull().sum() 
print('so there are '+ str(missing_vals) + ' missing values in price column')
# Out:
# so there are 0 missing values in price column

# %%
x = house.drop('price',axis=1)
y = house['price']
print(x)
print(y)
print('shape of x = ', x.shape)
print('shape of y = ', y.shape)
# Out:
#       bath  balcony  total_sqft_int  bhk  price_per_sqft  \
# 0      3.0      2.0          1672.0    3     8971.291866
# 1      3.0      3.0          1750.0    3     8514.285714
# 2      3.0      2.0          1750.0    3     8571.428571
# 3      2.0      2.0          1250.0    2     3200.000000
# 4      2.0      2.0          1200.0    2     6916.666667
# ...    ...      ...             ...  ...             ...
# 7115   3.0      2.0          2900.0    3    11206.896552
# 7116   3.0      1.0          1780.0    3     4765.730337
# 7117   2.0      1.0           880.0    2     5454.545455
# 7118   2.0      1.0          1000.0    2     5500.000000
# 7119   2.0      1.0          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# 1                                 0                        1
# 2                                 1                        0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print('shape of x_train =', x_train.shape)
print('shape of y_train =', y_train.shape)
print('shape of x_test =', x_train.shape)
print('shape of y_test =', y_train.shape)
# Out:
# shape of x_train = (5696, 107)
# shape of y_train = (5696,)
# shape of x_test = (5696, 107)
# shape of y_test = (5696,)

# %%
x=np.array(x)
print(x)
# Out:
# [[3.000e+00 2.000e+00 1.672e+03 ... 0.000e+00 0.000e+00 0.000e+00]
#  [3.000e+00 3.000e+00 1.750e+03 ... 0.000e+00 0.000e+00 0.000e+00]
#  [3.000e+00 2.000e+00 1.750e+03 ... 0.000e+00 0.000e+00 0.000e+00]
#  ...
#  [2.000e+00 1.000e+00 8.800e+02 ... 0.000e+00 0.000e+00 0.000e+00]
#  [2.000e+00 1.000e+00 1.000e+03 ... 0.000e+00 0.000e+00 0.000e+00]
#  [2.000e+00 1.000e+00 1.400e+03 ... 0.000e+00 0.000e+00 0.000e+00]]

# %%
import matplotlib.pyplot as plt
plt.plot(x,y, 'g.')
plt.xlabel("x")
plt.ylabel("price")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x_train)
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)
print(x_train)
print(x_test)
# Out:
# [[-0.44422611  0.54630035  0.07232582 ... -0.04782807 -0.05138463
#   -0.04782807]
#  [ 0.6879045   1.83462341  0.17729421 ... -0.04782807 -0.05138463
#   -0.04782807]
#  [-0.44422611 -0.74202271 -0.50500027 ... -0.04782807 -0.05138463
#   -0.04782807]
#  ...
#  [-0.44422611  0.54630035 -0.35279612 ... -0.04782807 -0.05138463
#   -0.04782807]
#  [ 0.6879045   0.54630035  0.98030232 ... -0.04782807 -0.05138463
#   -0.04782807]
#  [-0.44422611  0.54630035 -0.12186568 ... -0.04782807 -0.05138463
#   -0.04782807]]
# [[-0.44422611  0.54630035 -0.34334897 ... -0.04782807 -0.05138463
#   -0.04782807]
#  [-0.44422611  0.54630035 -0.27826857 ... -0.04782807 -0.05138463
#   -0.04782807]
#  [-0.44422611 -0.74202271 -0.29716288 ... -0.04782807 -0.05138463
#   -0.04782807]
#  ...
#  [-0.44422611  0.54630035 -0.35909422 ... -0.04782807 -0.05138463
#   -0.04782807]
#  [-0.44422611 -0.74202271 -0.69604273 ... -0.04782807 -0.05138463
#   -0.04782807]
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.coef_.shape)
# Out:
# [ 2.10697065e+00 -2.17344834e-01  8.09618462e+01 -1.24299891e+01
#   6.46517341e+01  1.03875798e+00 -4.22390680e-01 -2.65025781e+00
#  -2.19644047e+00 -3.49542058e+00 -2.41964049e+00  5.18163738e-01
#  -9.85932364e-01  2.03844761e+00  4.46666102e-01 -1.52874675e+00
#  -2.62459460e-01  2.60433514e+00 -1.51294200e+00  2.14934596e+00
#  -2.86208603e+00 -1.66252417e+00 -7.95799325e-01 -8.62504507e-02
#   1.07791797e+00  1.96293241e+00 -5.04836289e+00 -8.69534019e-01
#  -4.98395153e-01  1.76024251e+00 -3.45079920e-01 -4.54048600e-01
#   7.04203932e-01 -1.34675947e+00  1.28669286e-01 -1.41551169e+00
#   4.51518203e-01  7.11760189e-01  3.18362190e+00  1.66133380e-01
#   5.49930798e-01  3.17196511e-01 -2.04326026e-01  1.19513163e+00
#  -1.64190125e+00 -3.13728979e+00 -1.55812680e-01  4.38329320e-02
#  -6.38027870e-01 -1.69795204e+00 -1.13734096e+00  6.08899775e-01
#   1.13372540e+00 -3.07142961e-01 -9.02518727e-01  1.43083295e+00
# ...

# %%
lr.intercept_
# Out:
# 96.10553809691011

# %%
x_test[0, :]
# Out:
# array([-0.44422611,  0.54630035, -0.34334897, -0.55044507, -0.72383255,
#         0.57680968, -0.47233992, -0.25703648,  0.50597314, -0.18727461,
#        -0.16162122, -0.15580825, -0.1288342 , -0.13023539, -0.12812824,
#        -0.12234347,  7.59747652, -0.12741862, -0.12234347, -0.10909925,
#        -0.1082724 , -0.1082724 , -0.11472827, -0.10743948, -0.09218776,
#        -0.09315135, -0.08823182, -0.08923672, -0.09023078, -0.08195215,
#        -0.08514823, -0.0830308 , -0.08514823, -0.07276497, -0.07975227,
#        -0.07975227, -0.07749158, -0.0739743 , -0.06901264, -0.0751646 ,
#        -0.07153563, -0.0751646 , -0.0751646 , -0.0751646 , -0.07749158,
#        -0.07633675, -0.07276497, -0.06901264, -0.0739743 , -0.07276497,
#        -0.07028523, -0.06504853, -0.0677166 , -0.0677166 , -0.0677166 ,
#        -0.06504853, -0.07153563, -0.06367332, -0.06226825, -0.06639573,
#        -0.06226825, -0.06367332, -0.06504853, -0.06504853, -0.06504853,
# ...

# %%
x_test[3, :-1]
# Out:
# array([ 1.82003511,  0.54630035,  1.48939898,  1.80872356,  2.07828941,
#         0.57680968, -0.47233992, -0.25703648,  0.50597314, -0.18727461,
#        -0.16162122, -0.15580825, -0.1288342 , -0.13023539, -0.12812824,
#        -0.12234347, -0.13162265, -0.12741862, -0.12234347, -0.10909925,
#        -0.1082724 , -0.1082724 , -0.11472827, -0.10743948, -0.09218776,
#        -0.09315135, -0.08823182, -0.08923672, -0.09023078, -0.08195215,
#        -0.08514823, -0.0830308 , -0.08514823, -0.07276497, -0.07975227,
#        -0.07975227, -0.07749158, -0.0739743 , -0.06901264, -0.0751646 ,
#        -0.07153563, -0.0751646 , -0.0751646 , -0.0751646 , -0.07749158,
#        -0.07633675, -0.07276497, -0.06901264, -0.0739743 , -0.07276497,
#        -0.07028523, -0.06504853, -0.0677166 , -0.0677166 , -0.0677166 ,
#        -0.06504853, -0.07153563, -0.06367332, -0.06226825, -0.06639573,
#        -0.06226825, -0.06367332, -0.06504853, -0.06504853, -0.06504853,
# ...

# %%
lr.predict([x_test[0, :]])
# Out:
# array([27.20184313])

# %%
y_pred = lr.predict(x_test)
print(y_pred)
import numpy as np
print(np.array(y_test))
# Out:
# [27.20184313 52.88038063 64.11169828 ... 51.13592971 11.96514123
#  34.76431452]
# [47.  60.  65.  ... 56.5 26.  49. ]

# %%
from sklearn.metrics import r2_score
print((r2_score(y_test,y_pred))*100)
#(x_test, y_test)
# Out:
# 91.9680813221159

# %%
house.corr()
# Out:
#                                  bath   balcony     price  total_sqft_int  \
# bath                         1.000000  0.283192  0.523941        0.653435
# balcony                      0.283192  1.000000  0.138946        0.200648
# price                        0.523941  0.138946  1.000000        0.797955
# total_sqft_int               0.653435  0.200648  0.797955        1.000000
# bhk                          0.882461  0.269511  0.497817        0.647485
# ...                               ...       ...       ...             ...
# location_Hosur Road          0.011201 -0.020262  0.000618        0.007224
# location_Horamavu Banaswadi -0.020635  0.022541 -0.021200       -0.015287
# location_Domlur              0.006606  0.000445  0.019573        0.007875
# location_Mahadevpura        -0.017608  0.008764 -0.015800       -0.011000
# location_Tumkur Road        -0.002474 -0.018788 -0.006216       -0.010931
#
#                                   bhk  price_per_sqft  \
# ...

# %%
sns.heatmap(house.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 5))
heatmap = sns.heatmap(house.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('correlation', fontdict={'fontsize':12}, pad=12);

# %%
#Checking distribution and outlier for each variable
plt.figure(2)
plt.subplot(121)
sns.distplot(house['area_typeSuper built-up  Area'])
plt.subplot(122)
house['area_typeSuper built-up  Area'].plot.box(figsize=(15,5))
# Out:
# C:\Users\sushmitha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='bath',y='balcony',data=house)
# Out:
# <AxesSubplot:xlabel='bath', ylabel='balcony'>

# %%
from sklearn.preprocessing import StandardScaler

# Assuming you have your input data stored in a variable called 'data'
X = house  # Assign the input data to the variable X

# Create an instance of StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data
scaler.fit(X)

# Transform the data using the fitted scaler
x_standard = scaler.transform(X)

# %%
scaler = StandardScaler()
pred_test = np.asarray(pred_test).reshape(1,-1)
scaler.fit(pred_test)
pred_test_std = scaler.transform(pred_test)

# %%
columns = ['bath', 'balcony', 'price', 'total_sqft_int', 'bhk', 'price_per_sqft']  # Replace with your actual column names

for column in columns:
    plt.figure(figsize=(25, 6))
    sns.countplot(x=house[column], data=house, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))  
sns.heatmap(house.corr(),annot=True,cmap = "crest")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(house.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#House price prediction completed
